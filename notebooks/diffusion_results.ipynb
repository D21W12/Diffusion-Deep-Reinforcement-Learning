# %%
# %cd ..
# Out:
# /scratch/big/home/daawic/BSc-Thesis

# %%
import os
from project.models import EDMEvelynn
from project.util.device import get_available_acc
from project.util.plotting import plot_sample

# %%
PATH = os.path.join("..", "checkpoints", "diff", "Breakout.pt")

# %%
device = "cuda:8"

# %%
model = EDMEvelynn.from_checkpoint(PATH, device).to(device)

# %%
x = model.sample(1)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# 100%|██████████| 32/32 [00:03<00:00, 10.65it/s]

# %%
plot_sample(x[0, :4])
