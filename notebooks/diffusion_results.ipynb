# %%
import os
import torch
from project.models import EDMEvelynn

# %%
PATH = os.path.join("..", "checkpoints", "diff", "ArchSimple.pt")

# %%
device = "cpu"
if torch.mps.is_available():
    device = "mps"
elif torch.cuda.is_available():
    device = "cuda"
print(f"Using: {device}")
# Out:
# Using: mps

# %%
model = EDMEvelynn.from_checkpoint(PATH, device)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model = EDMEvelynn.from_checkpoint(PATH, device)
#
# File ~/PycharmProjects/BSc Thesis/project/models/edm.py:20, in EDMEvelynn.from_checkpoint(cls, f, device)
#      17 checkpoint = torch.load(f, map_location=device)
#      18 kwargs = checkpoint["config"]
# ---> 20 model = cls(**kwargs)
#      21 return model.load(f)
#
# File ~/PycharmProjects/BSc Thesis/project/models/edm.py:66, in EDMEvelynn.__init__(self, img_resolution, img_channels, model_channels, channel_mult, num_blocks, attn_resolutions, dropout, batch_size, lr, N, sigma_min, sigma_max, sigma_data, rho, P_mean, P_std, network)
#      64 # Initializing score network
#      65 if network == "edm2":
# ---> 66     self._score_network = EDM2UNet(
#      67         img_resolution=img_resolution,
#      68         img_channels=img_channels,
#      69         model_channels=model_channels,
#      70         num_blocks=num_blocks,
#      71         channel_mult=channel_mult,
#      72         attn_resolutions=attn_resolutions,
#      73     )
#      74 elif network == "ddpm":
#      75     self._score_network = UNetEvelynn(
#      76         img_resolution=img_resolution,
#      77         img_channels=img_channels,
#    (...)     83         dropout=dropout
#      84     )
#
# File ~/PycharmProjects/BSc Thesis/project/nn/edm2.py:212, in UNet.__init__(self, img_resolution, img_channels, label_dim, model_channels, channel_mult, channel_mult_noise, channel_mult_emb, num_blocks, attn_resolutions, label_balance, concat_balance, **block_kwargs)
#     209 self.out_gain = torch.nn.Parameter(torch.zeros([]))
#     211 # Embedding.
# --> 212 self.emb_fourier = MPFourier(cnoise)
#     213 self.emb_noise = MPConv(cnoise, cemb, kernel=[])
#     214 self.emb_label = MPConv(label_dim, cemb, kernel=[]) if label_dim != 0 else None
#
# File ~/PycharmProjects/BSc Thesis/project/nn/edm2.py:85, in MPFourier.__init__(self, num_channels, bandwidth)
#      83 def __init__(self, num_channels, bandwidth=1):
#      84     super().__init__()
# ---> 85     self.register_buffer('freqs', 2 * np.pi * torch.randn(num_channels) * bandwidth)
#      86     self.register_buffer('phases', 2 * np.pi * torch.rand(num_channels))
#
# RuntimeError: Storage size calculation overflowed with sizes=[1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 2]
