# %%
# %cd ..
# Out:
# /Users/daanwichmann/PycharmProjects/BSc Thesis

# %%
import os
from project.models import EDMEvelynn
from project.util.device import get_available_acc
from project.util.plotting import plot_sample

# %%
PATH = os.path.join("checkpoints", "diff", "ArchSimple.pt")

# %%
device = get_available_acc()
device
# Out:
# 'mps'

# %%
model = EDMEvelynn.from_checkpoint(PATH, device)

# %%
x = model.sample(1)
plot_sample(x[0])
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 x = model.sample(1)
#       2 plot_sample(x[0])
#
# File ~/PycharmProjects/BSc Thesis/project/models/edm.py:249, in EDMEvelynn.sample(self, batch_size)
#     245 x_next = x_i
#     247 for i in trange(0, self._N):
# --> 249     d_i = self._dx_dt(x_next, self._t(i))
#     250     x_prime = x_next + (self._t(i + 1) - self._t(i)) * d_i
#     252     # Apply second order correction unless sigma goes to zero
#
# File ~/PycharmProjects/BSc Thesis/project/models/edm.py:149, in EDMEvelynn._dx_dt(self, x, t)
#     146 batch_sigma = torch.full((x.shape[0],), self._sigma(t), device=self._device)
#     148 a = (self._sigma_dot(t) / self._sigma(t) + self._s_dot(t) / self._s(t)) * x
# --> 149 b = self._sigma_dot(t) * self._s(t) / self._sigma(t) * self._D(x / self._s(t), batch_sigma)
#     151 return a - b
#
# File ~/PycharmProjects/BSc Thesis/project/models/edm.py:174, in EDMEvelynn._D(self, x, sigmas)
#     171     c_noise = self._c_noise(sigmas)
#     173 x_in = (c_in * x).to(self._dtype)
# --> 174 return c_skip * x + c_out * self._F(x_in, c_noise).to(torch.float32)
#
# File ~/PycharmProjects/BSc Thesis/project/models/edm.py:158, in EDMEvelynn._F(self, x, sigma)
#     153 def _F(
#     154         self,
#     155         x: torch.Tensor,
#     156         sigma: torch.Tensor
#     157 ) -> torch.Tensor:
# --> 158     y = self._score_network(x, sigma)
#     159     return y
#
# File ~/PycharmProjects/BSc Thesis/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/PycharmProjects/BSc Thesis/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/PycharmProjects/BSc Thesis/project/nn/edm2.py:273, in UNet.forward(self, x, noise_labels, class_labels)
#     271     if 'block' in name:
#     272         x = mp_cat(x, skips.pop(), t=self.concat_balance)
# --> 273     x = block(x, emb)
#     274 x = self.out_conv(x, gain=self.out_gain)
#     275 return x
#
# File ~/PycharmProjects/BSc Thesis/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/PycharmProjects/BSc Thesis/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/PycharmProjects/BSc Thesis/project/nn/edm2.py:158, in Block.forward(self, x, emb)
#     155     x = normalize(x, dim=1) # pixel norm
#     157 # Residual branch.
# --> 158 y = self.conv_res0(mp_silu(x))
#     159 c = self.emb_linear(emb, gain=self.emb_gain) + 1
#     160 y = mp_silu(y * c.unsqueeze(2).unsqueeze(3).to(y.dtype))
#
# File ~/PycharmProjects/BSc Thesis/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/PycharmProjects/BSc Thesis/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/PycharmProjects/BSc Thesis/project/nn/edm2.py:113, in MPConv.forward(self, x, gain)
#     111     return x @ w.t()
#     112 assert w.ndim == 4
# --> 113 return torch.nn.functional.conv2d(x, w, padding=(w.shape[-1]//2,))
#
# KeyboardInterrupt:
