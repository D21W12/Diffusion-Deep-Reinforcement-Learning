# %%
# %cd ..
# Out:
# /Users/daanwichmann/PycharmProjects/BSc Thesis

# %%
from project.nn import UNet

# %%
model = UNet(
    resolution=120,
    in_channels=4,
    start_channels=128,
    out_channels=4,
    num_res_blocks=1,
    channel_multipliers=(1, 2, 4, 8),
    attention_resolutions=[],
)

# %%
print(sum(p.numel() for p in model.parameters() if p.requires_grad))
# Out:
# 83913316
