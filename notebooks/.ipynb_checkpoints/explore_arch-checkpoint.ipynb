# %%
# %cd ..
# Out:
# C:\Users\daanw\PycharmProjects\BSc-Thesis

# %%
import os
import torch
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision import transforms
from project.models import EDMEvelynn
from project.util.data import ReplayMemoryData
from project.util.transforms import FP16Precision

# %%
device = "cpu"
if torch.mps.is_available():
    device = "mps"
elif torch.cuda.is_available():
    device = "cuda"
    torch.backends.cudnn.allow_tf32 = False
    torch.backends.cuda.matmul.allow_tf32 = False
    torch.backends.cuda.matmul.allow_fp16_reduced_precision_reduction = False
print(f"Using: {device}")
# Out:
# Using: cuda

# %%
DATA = os.path.join("checkpoints", "memory", "AdamW25e5.pt")

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    # FP16Precision(),
    transforms.Normalize(0.5, 0.5),
    transforms.Pad(2),
])

# %%
data = ReplayMemoryData(
    memory=DATA,
    transform=transform,
    cap=100_000
)

# %%
loader = DataLoader(data, batch_size=4, shuffle=True)

# %%
data[1].dtype
# Out:
# torch.float32

# %%
image = (data[50]).mean(dim=0)
plt.imshow(image)
plt.grid(None)
plt.show()

# %%
model = EDMEvelynn(
    img_resolution=88,
    img_channels=4,
    model_channels=128,
    channel_mult=[1, 2, 2, 2],
    attn_resolutions=[22, 11],
).to(device)
# Out:
# Attention for 88: False
# Attention for 88: False
# Attention for 88: False
# Attention for 44: False
# Attention for 44: False
# Attention for 44: False
# Attention for 22: True
# Attention for 22: True
# Attention for 22: True
# Attention for 11: True
# Attention for 11: True
# Attention for 11: True

# %%
model.train(1, loader)
# Out:
# Epoch 1:   0%|█▏                                                                                                                                                                                                                                                          | 120/25000 [00:32<1:53:48,  3.64it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 model.train(1, loader)
#
# File ~\PycharmProjects\BSc-Thesis\project\models\edm.py:211, in EDMEvelynn.train(self, epochs, dataloader, print_loss, wandb)
#     209 self._score_network.train()
#     210 for epoch in range(epochs):
# --> 211     self._run_epoch(dataloader, print_loss=print_loss, wandb=wandb)
#
# File ~\PycharmProjects\BSc-Thesis\project\models\edm.py:194, in EDMEvelynn._run_epoch(self, dataloader, print_loss, wandb)
#     192 desc = f"Epoch {self._epochs + 1}"
#     193 for batch in tqdm(dataloader, desc=desc):
# --> 194     loss += self._run_batch(batch.to(self._device))
#     196 self._epochs += 1
#     198 loss /= len(dataloader.dataset)
#
# File ~\PycharmProjects\BSc-Thesis\project\models\edm.py:173, in EDMEvelynn._run_batch(self, y)
#     170 n = torch.randn_like(y) * sigma[:, None, None, None]
#     171 yn = y + n
# --> 173 D_yn = self._D(yn, sigma)
#     175 # Doing a gradient descent step
#     176 self._optimizer.zero_grad()
#
# File ~\PycharmProjects\BSc-Thesis\project\models\edm.py:156, in EDMEvelynn._D(self, x, sigmas)
#     153     c_noise = self._c_noise(sigmas)
#     154     x_in = (c_in * x).to(torch.float16)
# --> 156 return c_skip * x + c_out * self._F(x_in, c_noise).to(torch.float32)
#
# File ~\PycharmProjects\BSc-Thesis\project\models\edm.py:140, in EDMEvelynn._F(self, x, sigma)
#     135 def _F(
#     136         self,
#     137         x: torch.Tensor,
#     138         sigma: torch.Tensor
#     139 ) -> torch.Tensor:
# --> 140     y = self._score_network(x, sigma)
#     141     return y
#
# File ~\PycharmProjects\BSc-Thesis\.venv\Lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~\PycharmProjects\BSc-Thesis\.venv\Lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~\PycharmProjects\BSc-Thesis\project\nn\edm2.py:267, in UNet.forward(self, x, noise_labels, class_labels)
#     265 skips = []
#     266 for name, block in self.enc.items():
# --> 267     x = block(x) if 'conv' in name else block(x, emb)
#     268     skips.append(x)
#     270 # Decoder.
#
# File ~\PycharmProjects\BSc-Thesis\.venv\Lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~\PycharmProjects\BSc-Thesis\.venv\Lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~\PycharmProjects\BSc-Thesis\project\nn\edm2.py:163, in Block.forward(self, x, emb)
#     161 if self.training and self.dropout != 0:
#     162     y = torch.nn.functional.dropout(y, p=self.dropout)
# --> 163 y = self.conv_res1(y)
#     165 # Connect the branches.
#     166 if self.flavor == 'dec' and self.conv_skip is not None:
#
# File ~\PycharmProjects\BSc-Thesis\.venv\Lib\site-packages\torch\nn\modules\module.py:1779, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1777     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1778 else:
# -> 1779     return self._call_impl(*args, **kwargs)
#
# File ~\PycharmProjects\BSc-Thesis\.venv\Lib\site-packages\torch\nn\modules\module.py:1790, in Module._call_impl(self, *args, **kwargs)
#    1785 # If we don't have any hooks, we want to skip the rest of the logic in
#    1786 # this function, and just call forward.
#    1787 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1788         or _global_backward_pre_hooks or _global_backward_hooks
#    1789         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790     return forward_call(*args, **kwargs)
#    1792 result = None
#    1793 called_always_called_hooks = set()
#
# File ~\PycharmProjects\BSc-Thesis\project\nn\edm2.py:109, in MPConv.forward(self, x, gain)
#     107 w = normalize(w) # traditional weight normalization
#     108 w = w * (gain / np.sqrt(w[0].numel())) # magnitude-preserving scaling
# --> 109 w = w.to(x.dtype)
#     110 if w.ndim == 2:
#     111     return x @ w.t()
#
# KeyboardInterrupt:

# %%
m
